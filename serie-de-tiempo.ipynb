# %%
pip install yahoo_fin --upgrade
# Out:
# Requirement already satisfied: yahoo_fin in c:\anaconda\envs\ambiente\lib\site-packages (0.8.9.1)
# Requirement already satisfied: feedparser in c:\anaconda\envs\ambiente\lib\site-packages (from yahoo_fin) (6.0.10)
# Requirement already satisfied: requests in c:\anaconda\envs\ambiente\lib\site-packages (from yahoo_fin) (2.31.0)
# Requirement already satisfied: pandas in c:\anaconda\envs\ambiente\lib\site-packages (from yahoo_fin) (1.5.1)
# Requirement already satisfied: requests-html in c:\anaconda\envs\ambiente\lib\site-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: sgmllib3k in c:\anaconda\envs\ambiente\lib\site-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\anaconda\envs\ambiente\lib\site-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\anaconda\envs\ambiente\lib\site-packages (from pandas->yahoo_fin) (1.23.4)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\envs\ambiente\lib\site-packages (from pandas->yahoo_fin) (2022.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\envs\ambiente\lib\site-packages (from requests->yahoo_fin) (1.26.16)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\envs\ambiente\lib\site-packages (from requests->yahoo_fin) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\envs\ambiente\lib\site-packages (from requests->yahoo_fin) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\envs\ambiente\lib\site-packages (from requests->yahoo_fin) (2.0.4)
# Requirement already satisfied: pyquery in c:\anaconda\envs\ambiente\lib\site-packages (from requests-html->yahoo_fin) (2.0.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\anaconda\envs\ambiente\lib\site-packages (from requests-html->yahoo_fin) (1.0.2)
# Requirement already satisfied: fake-useragent in c:\anaconda\envs\ambiente\lib\site-packages (from requests-html->yahoo_fin) (1.2.1)
# Requirement already satisfied: bs4 in c:\anaconda\envs\ambiente\lib\site-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: parse in c:\anaconda\envs\ambiente\lib\site-packages (from requests-html->yahoo_fin) (1.19.1)
# Requirement already satisfied: w3lib in c:\anaconda\envs\ambiente\lib\site-packages (from requests-html->yahoo_fin) (2.1.2)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\anaconda\envs\ambiente\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (6.8.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\anaconda\envs\ambiente\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\anaconda\envs\ambiente\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.66.1)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\anaconda\envs\ambiente\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (10.4)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in c:\anaconda\envs\ambiente\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: six>=1.5 in c:\anaconda\envs\ambiente\lib\site-packages (from python-dateutil>=2.8.1->pandas->yahoo_fin) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in c:\anaconda\envs\ambiente\lib\site-packages (from bs4->requests-html->yahoo_fin) (4.11.1)
# Requirement already satisfied: cssselect>=1.2.0 in c:\anaconda\envs\ambiente\lib\site-packages (from pyquery->requests-html->yahoo_fin) (1.2.0)
# Requirement already satisfied: lxml>=2.1 in c:\anaconda\envs\ambiente\lib\site-packages (from pyquery->requests-html->yahoo_fin) (4.9.3)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda\envs\ambiente\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.16.2)
# Requirement already satisfied: colorama in c:\anaconda\envs\ambiente\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests-html->yahoo_fin) (0.4.5)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconda\envs\ambiente\lib\site-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.3.2.post1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydataset
# Out:
# Collecting pydataset
#   Downloading pydataset-0.2.0.tar.gz (15.9 MB)
#      ---------------------------------------- 15.9/15.9 MB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas in c:\anaconda\envs\ambiente\lib\site-packages (from pydataset) (1.5.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\anaconda\envs\ambiente\lib\site-packages (from pandas->pydataset) (1.23.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\anaconda\envs\ambiente\lib\site-packages (from pandas->pydataset) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\envs\ambiente\lib\site-packages (from pandas->pydataset) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\anaconda\envs\ambiente\lib\site-packages (from python-dateutil>=2.8.1->pandas->pydataset) (1.16.0)
# Building wheels for collected packages: pydataset
#   Building wheel for pydataset (setup.py): started
#   Building wheel for pydataset (setup.py): finished with status 'done'
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939417 sha256=053d51be3a249f71e2f0f20bea0586c67688e3c5e6110c44e8c5f7d7cd52816a
#   Stored in directory: c:\users\nelcy\appdata\local\pip\cache\wheels\2b\83\5c\073c3755e8b7704e4677557b2055e61026c1a2342149214c13
# Successfully built pydataset
# Installing collected packages: pydataset
# Successfully installed pydataset-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests_html
# Out:
# Requirement already satisfied: requests_html in c:\anaconda\envs\ambiente\lib\site-packages (0.10.0)
# Requirement already satisfied: pyquery in c:\anaconda\envs\ambiente\lib\site-packages (from requests_html) (2.0.0)
# Requirement already satisfied: parse in c:\anaconda\envs\ambiente\lib\site-packages (from requests_html) (1.19.1)
# Requirement already satisfied: fake-useragent in c:\anaconda\envs\ambiente\lib\site-packages (from requests_html) (1.2.1)
# Requirement already satisfied: w3lib in c:\anaconda\envs\ambiente\lib\site-packages (from requests_html) (2.1.2)
# Requirement already satisfied: requests in c:\anaconda\envs\ambiente\lib\site-packages (from requests_html) (2.31.0)
# Requirement already satisfied: bs4 in c:\anaconda\envs\ambiente\lib\site-packages (from requests_html) (0.0.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\anaconda\envs\ambiente\lib\site-packages (from requests_html) (1.0.2)
# Requirement already satisfied: certifi>=2021 in c:\anaconda\envs\ambiente\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (2022.12.7)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in c:\anaconda\envs\ambiente\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (8.2.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\anaconda\envs\ambiente\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\anaconda\envs\ambiente\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (6.8.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\anaconda\envs\ambiente\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.26.16)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\anaconda\envs\ambiente\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (4.66.1)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\anaconda\envs\ambiente\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (10.4)
# Requirement already satisfied: beautifulsoup4 in c:\anaconda\envs\ambiente\lib\site-packages (from bs4->requests_html) (4.11.1)
# Requirement already satisfied: cssselect>=1.2.0 in c:\anaconda\envs\ambiente\lib\site-packages (from pyquery->requests_html) (1.2.0)
# Requirement already satisfied: lxml>=2.1 in c:\anaconda\envs\ambiente\lib\site-packages (from pyquery->requests_html) (4.9.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\envs\ambiente\lib\site-packages (from requests->requests_html) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\envs\ambiente\lib\site-packages (from requests->requests_html) (2.0.4)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda\envs\ambiente\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.16.2)
# Requirement already satisfied: colorama in c:\anaconda\envs\ambiente\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests_html) (0.4.5)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconda\envs\ambiente\lib\site-packages (from beautifulsoup4->bs4->requests_html) (2.3.2.post1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\anaconda\envs\ambiente\lib\site-packages (0.13.2)
# Requirement already satisfied: scipy>=1.3 in c:\anaconda\envs\ambiente\lib\site-packages (from statsmodels) (1.9.3)
# Requirement already satisfied: packaging>=21.3 in c:\anaconda\envs\ambiente\lib\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\anaconda\envs\ambiente\lib\site-packages (from statsmodels) (1.23.4)
# Requirement already satisfied: patsy>=0.5.2 in c:\anaconda\envs\ambiente\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: pandas>=0.25 in c:\anaconda\envs\ambiente\lib\site-packages (from statsmodels) (1.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\anaconda\envs\ambiente\lib\site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\envs\ambiente\lib\site-packages (from pandas>=0.25->statsmodels) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\anaconda\envs\ambiente\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in c:\anaconda\envs\ambiente\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importo librias

# %%
from yahoo_fin.stock_info import get_data

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from   matplotlib import style
style.use('ggplot')

# %%
 nvidia = get_data("NVDA", start_date = "2018-01-1", end_date ="2023-09-7",index_as_date = True, interval="1d")

# %%
nvidia.head()
# Out:
#                  open       high        low      close   adjclose    volume  \
# 2018-01-02  48.945000  49.875000  48.625000  49.837502  49.317120  35561600
# 2018-01-03  51.025002  53.424999  50.937500  53.117500  52.562870  91470400
# 2018-01-04  53.939999  54.512501  53.172501  53.397499  52.839954  58326800
# 2018-01-05  53.547501  54.227501  52.770000  53.849998  53.287727  58012400
# 2018-01-08  55.099998  56.250000  54.645000  55.500000  54.920498  88121600
#
#            ticker
# 2018-01-02   NVDA
# 2018-01-03   NVDA
# 2018-01-04   NVDA
# 2018-01-05   NVDA
# 2018-01-08   NVDA

# %%
nvidia.tail()
# Out:
#                   open        high         low       close    adjclose  \
# 2023-08-30  490.440002  499.269989  484.250000  492.640015  492.599426
# 2023-08-31  493.799988  497.440002  489.579987  493.549988  493.509338
# 2023-09-01  497.619995  498.000000  481.420013  485.089996  485.050049
# 2023-09-05  482.230011  488.510010  478.600006  485.480011  485.440033
# 2023-09-06  484.410004  485.489990  465.799988  470.609985  470.609985
#
#               volume ticker
# 2023-08-30  73520600   NVDA
# 2023-08-31  52857000   NVDA
# 2023-09-01  46319100   NVDA
# 2023-09-05  38265300   NVDA
# 2023-09-06  46867000   NVDA

# %%
nvidia['2020-01-01':'2023-09-1']
# Out:
#                   open        high         low       close    adjclose  \
# 2020-01-02   59.687500   59.977501   59.180000   59.977501   59.749298
# 2020-01-03   58.775002   59.457500   58.525002   59.017502   58.792950
# 2020-01-06   58.080002   59.317501   57.817501   59.264999   59.039509
# 2020-01-07   59.549999   60.442501   59.097500   59.982498   59.754284
# 2020-01-08   59.939999   60.509998   59.537498   60.095001   59.866348
# ...                ...         ...         ...         ...         ...
# 2023-08-28  464.820007  469.799988  448.880005  468.350006  468.311432
# 2023-08-29  466.660004  490.809998  463.910004  487.839996  487.799805
# 2023-08-30  490.440002  499.269989  484.250000  492.640015  492.599426
# 2023-08-31  493.799988  497.440002  489.579987  493.549988  493.509338
# 2023-09-01  497.619995  498.000000  481.420013  485.089996  485.050049
#
#               volume ticker
# 2020-01-02  23753600   NVDA
# 2020-01-03  20538400   NVDA
# 2020-01-06  26263600   NVDA
# 2020-01-07  31485600   NVDA
# 2020-01-08  27710800   NVDA
# ...              ...    ...
# 2023-08-28  68519200   NVDA
# 2023-08-29  70139700   NVDA
# 2023-08-30  73520600   NVDA
# 2023-08-31  52857000   NVDA
# 2023-09-01  46319100   NVDA
#
# [924 rows x 7 columns]

# %%
# valores de nvidia 2022-9-1
nvidia.loc["2022-9-1"]
# Out:
# open        142.089996
# high        143.800003
# low         132.699997
# close       139.369995
# adjclose    139.243423
# volume       117886500
# ticker            NVDA
# Name: 2022-09-01 00:00:00, dtype: object

# %%
# Costo de la accion cuando cerro el mercado
nvidia["adjclose"]["2023-9-1"]
# Out:
# 485.050048828125

# %%
#cada trimestre
 t_nvidia = nvidia.asfreq('BQ')

# %% [markdown]
# # Graficamos

# %%
nvidia['adjclose'].plot()
plt.title('Nvida a lo largo de los años')
plt.show()

# %%
desplazado = nvidia['adjclose'].shift(1)
desplazado[:5]
# Out:
# 2018-01-02          NaN
# 2018-01-03    49.317120
# 2018-01-04    52.562870
# 2018-01-05    52.839954
# 2018-01-08    53.287727
# Name: adjclose, dtype: float64

# %%
# calculando el porcentaje de variación del día.
nvidia['adjclose'].pct_change()[:5]
# Out:
# 2018-01-02         NaN
# 2018-01-03    0.065814
# 2018-01-04    0.005271
# 2018-01-05    0.008474
# 2018-01-08    0.030641
# Name: adjclose, dtype: float64

# %%
import statsmodels.api as sm 
nvidia_ciclo, nvidia_tend = sm.tsa.filters.hpfilter(nvidia['adjclose'])
nvidia['tend'] = nvidia_tend

# %%
fig, ax = plt.subplots(figsize=(10, 8))
nvidia['adjclose'].plot(ax=ax, color='green', label='Precio Real', fontsize=8)
nvidia['tend'].plot(ax=ax, color='red', label='Tendencia', fontsize=8)

legend = ax.legend()
legend.prop.set_size(8)

plt.show()
fig.savefig('grafica_descomposicion.png')

# %% [markdown]
# # Pronosticando la serie con ARIMA

# %%
# Calculando promedios móviles cada 5 días
nvidia['prod_mov'] = nvidia['adjclose'].rolling(window=5).mean()

# Creando un gráfico de variación del precio real con el promedio móvil
fig, ax = plt.subplots(figsize=(10, 8))
nvidia[['adjclose', 'prod_mov']].plot(ax=ax, fontsize=12)


legend = ax.legend(['Precio Real', 'Promedio Móvil'], fontsize=14)
plt.show()
